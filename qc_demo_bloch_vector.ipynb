# %% [markdown]
# <a href="https://colab.research.google.com/github/taxfree-python/quantum_computer_demo/blob/main/qc_demo_bloch_vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # visualization Bloch sphere

# %%
from qiskit.visualization import plot_bloch_multivector
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# %% [markdown]
# ## X gate

# %%
# 初期状態の量子ビットを準備（|0⟩ 状態）
initial_state = Statevector.from_label('0')
plot_bloch_multivector(initial_state, title="Initial State |0⟩")

# %%
# Xゲートを適用する量子回路を準備
qc = QuantumCircuit(1)
qc.x(0)

# Xゲート適用後の状態ベクトルを取得
final_state = initial_state.evolve(qc)

# 初期状態をプロット

# Xゲート適用後の状態をプロット
plot_bloch_multivector(final_state, title="After X Gate")

# %% [markdown]
# ## Z gate

# %%
# 初期状態の量子ビットを準備（|0⟩ 状態）
initial_state = Statevector.from_label('0')
plot_bloch_multivector(initial_state, title="Initial State |0⟩")

# %%
# Xゲートを適用する量子回路を準備
qc = QuantumCircuit(1)
qc.z(0)

# Xゲート適用後の状態ベクトルを取得
final_state = initial_state.evolve(qc)

# 初期状態をプロット

# Xゲート適用後の状態をプロット
plot_bloch_multivector(final_state, title="After Z Gate")

# %% [markdown]
# ## H gate

# %%
# 初期状態の量子ビットを準備（|0⟩ 状態）
initial_state = Statevector.from_label('0')
plot_bloch_multivector(initial_state, title="Initial State |0⟩")

# %%
# Xゲートを適用する量子回路を準備
qc = QuantumCircuit(1)
qc.h(0)

# Xゲート適用後の状態ベクトルを取得
final_state = initial_state.evolve(qc)

# 初期状態をプロット

# Xゲート適用後の状態をプロット
plot_bloch_multivector(final_state, title="After H Gate")
